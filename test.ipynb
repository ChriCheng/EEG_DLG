# %%
X, y, metadata = paradigm.get_data(dataset=dataset, subjects=[subj])
print(list(metadata.columns))
print(metadata.head())
print("nunique session:", metadata["session"].nunique() if "session" in metadata else None)
print("nunique run:", metadata["run"].nunique() if "run" in metadata else None)
